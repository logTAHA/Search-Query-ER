# %% [markdown]
# ## Data Preprocessing
# ---
#
# - **Data normalization**
# - **No tokenization required**

# %%
import sys
sys.path.append("..")

# %%
from src.preprocess import PreprocessData

# %% [markdown]
# #### Read .txt file

# %%
# Current data version
data_version = "v01"
# Write your file path here
input_path = "C:\\Users\\CNE\\Desktop\\data.txt"
output_path = f"../data/raw/{data_version}/data.txt"

# %%
ppd = PreprocessData()
with open(input_path, "r", encoding="utf-8") as fin, \
    open(output_path, "w", encoding="utf-8") as fout:
    for line in fin:
        result = ppd.prepare_text(line)
        fout.write(result)
